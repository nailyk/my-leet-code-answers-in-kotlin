// %%
fun triangleNumber(nums: IntArray): Int {

    nums.sort()

    for (i in 0 until nums.size - 2) {

        var left = i+1
        var right = nums.size - 1

        val valid = nums[i] + nums[left] > nums[j + 1]
    }
}
